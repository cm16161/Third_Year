# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image

# %%
img = cv2.imread('gradients.jpg')

# %%
img = cv2.imread('gradients.jpg',0)
edges = cv2.Canny(img,100,200)

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
#img = cv2.imread('home/chetan/Pictures/gradients.jpg',0)

laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
img1 = cv2.imread("gradients.jpg",0)
img2 = edges
#gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
#plt.subplot(121), plt.imshow(img2)
height, width = img.shape[:2]
print(height, width)
M = np.float32([[1,0,100],[0,1,50]])
#img2 = cv2.warpAffine(sobely,M,(width,height))
height2,width2 = img2.shape[:2]
print(height2, width2)
output = np.ones((height, width))
#print("pigeon")
alpha=0.5
beta=1-alpha
gamma=0
#dst = img1*alpha + img2*beta + gamma;
dst = np.uint8(alpha*(img1)+beta*(img2))
# cv2.addWeighted(gray,1, img2,1,0,dst,-1)
plt.subplot(121), plt.imshow(dst)
# Out:
# 487 450
# 487 450
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc638216550>,
#  <matplotlib.image.AxesImage at 0x7fc6382eeba8>)
