# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
from PIL import Image

# %%
img1 = cv2.imread("Strong-Lines-San-Francisco.jpg",0)
img2 = cv2.imread("flowers.jpg",0)

laplacian = cv2.Laplacian(img1,cv2.CV_64F)
sobelx = cv2.Sobel(img1,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img1,cv2.CV_64F,0,1,ksize=5)

height, width = img1.shape[:2]
img2 =cv2.resize(img2,(width,height))

alpha=0.1
beta=1-alpha
gamma=0
dst = np.uint8(alpha*(sobelx)+beta*(img2))
dst = cv2.applyColorMap(dst,cv2.COLORMAP_HSV)
plt.subplot(121), plt.imshow(dst)
cv2.imwrite("flower_sanfranlines.png",dst)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f2cf8c902e8>,
#  <matplotlib.image.AxesImage at 0x7f2cf4301390>)
